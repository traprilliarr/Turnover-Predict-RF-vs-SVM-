# %%
import pandas as pd
df = pd.read_csv('./turnover.csv', encoding = 'ISO-8859-1')

train = df.sample(frac=0.8, random_state=42)
test = df.loc[~df.index.isin(train.index)]

# %%
train.head()
# Out:
#            stag  event gender   age     industry profession traffic    coach  \
# 743   79.540041      0      m  23.0           IT         IT   youjs  my head
# 1010   7.129363      1      f  21.0      Consult         HR   youjs  my head
# 1123   6.669405      0      f  27.0        Banks         HR   youjs       no
# 140   20.041068      1      f  25.0  manufacture         HR  advert      yes
# 554    3.811088      1      f  32.0          etc  Marketing   youjs       no
#
#      head_gender greywage  way  extraversion  independ  selfcontrol  anxiety  \
# 743            m    white  car           4.6       5.5          8.7      4.8
# 1010           m    white  bus           5.4       6.9          7.2      2.5
# 1123           f    white  bus           9.4       5.5          3.3      4.0
# 140            f    white  car           9.4       3.4          1.8      8.7
# 554            m    white  bus           3.8       6.2          6.4      4.0
#
#       novator
# 743       4.4
# 1010      4.4
# 1123      7.5
# 140       7.5
# 554       6.0

# %%
test.head()
# Out:
#          stag  event gender   age industry           profession  traffic  \
# 1   22.965092      1      m  33.0    Banks                   HR    empjs
# 13   8.936345      1      f  24.0    State                  etc   advert
# 14  33.577002      1      f  25.0      etc                   HR       KA
# 20  45.371663      1      f  29.0      etc                   HR  referal
# 21  36.960986      1      f  48.0    State  BusinessDevelopment    empjs
#
#       coach head_gender greywage   way  extraversion  independ  selfcontrol  \
# 1        no           m    white   bus           6.2       4.1          5.7
# 13      yes           f    white  foot           7.0       6.2          4.1
# 14  my head           f    white  foot           9.4       1.2          4.1
# 20       no           m    white   bus           3.8       3.4          5.7
# 21       no           f    white   bus           4.6       6.2          4.9
#
#     anxiety  novator
# 1       7.1      8.3
# 13      7.1      9.0
# 14      5.6      6.7
# 20      8.7      7.5
# 21      5.6      6.7

# %%
train.to_csv("./train.csv", encoding='ISO-8859-1', index=False)

# %%
test.to_csv("./test.csv", encoding='ISO-8859-1', index=False)
